# %%
import pandas as pd

# %%
df_pos = pd.read_csv('data/combined_cleaned_data/final_pos.csv')
df_neg = pd.read_csv('data/combined_cleaned_data/final_neg.csv')

# %%
df = pd.read_csv('data/combined_cleaned_data/combined_with_fe.csv')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10108\105442801.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/combined_cleaned_data/combined_with_fe.csv')

# %%
df.asin.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        B0009RF9DW
# 1        B0012Y0ZG2
# 2        B0012Y0ZG2
# 3        B000FI4S1E
# 4        B0012Y0ZG2
#             ...
# 73619    B000YIYB3K
# 73620    B003VJPMT6
# 73621    B00FWK8UWI
# 73622    B000B9RI14
# 73623    B006VB2UNM
# Name: asin, Length: 73624, dtype: object>

# %%
df.shape
# Out:
# (73624, 16)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'overall', 'verified', 'reviewTime',
#        'reviewerID', 'asin', 'style', 'reviewerName', 'reviewText', 'summary',
#        'unixReviewTime', 'vote', 'image', 'review_clean', 'sentiment'],
#       dtype='object')

# %%
df.drop(df.columns[[0, 1]], axis = 1, inplace=True)

# %%
df.dropna(subset=['reviewText', 'review_clean', 'summary'], inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index  overall  verified   reviewTime      reviewerID        asin  \
# 0      0        5      True  09 24, 2013  A3CZ890UHC8HHZ  B0009RF9DW
# 1      1        5     False  07 12, 2014  A125TMC44CJBKK  B0012Y0ZG2
# 2      2        5      True  12 28, 2014  A3JDSBP01M7R2R  B0012Y0ZG2
# 3      3        5      True   03 3, 2014  A2HT5WENL8E5S6  B000FI4S1E
# 4      4        5     False   11 7, 2014   A7LAYX9R7IMOO  B0012Y0ZG2
#
#                   style     reviewerName  \
# 0  {'Size:': ' 6.6 oz'}  Amazon Customer
# 1   {'Size:': ' B-020'}   Mustang Shelly
# 2     {'Size:': ' 112'}    Tim A. Brooks
# 3                   NaN    Shasta Masser
# 4     {'Size:': ' 123'}       andre luiz
#
#                                           reviewText                summary  \
# 0  It diffuses a very mild light perfume, just wh...        What I expected
# 1  All time favorite!!!! Wish they still carried ...             Five Stars
# ...

# %%
df.drop('index', axis='columns', inplace=True)

# %%
df.drop(['reviewTime', 'asin', 'style', 'reviewerName', 'unixReviewTime', 'vote', 'image'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    overall  verified      reviewerID  \
# 0        5      True  A3CZ890UHC8HHZ
# 1        5     False  A125TMC44CJBKK
# 2        5      True  A3JDSBP01M7R2R
# 3        5      True  A2HT5WENL8E5S6
# 4        5     False   A7LAYX9R7IMOO
#
#                                           reviewText                summary  \
# 0  It diffuses a very mild light perfume, just wh...        What I expected
# 1  All time favorite!!!! Wish they still carried ...             Five Stars
# 2                        One of my wife's favorites.             Five Stars
# 3  If you have body acne this product is a must. ...  Acne Body Wash A MUST
# 4                        I really is what I expected             Five Stars
#
#                                         review_clean sentiment
# 0  wear mild perfume nice strong lotion day perfu...  Positive
# 1                     time still favorite carry wish  Positive
# 2                               one favorites wife's  Positive
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['sentiment'] = lb.fit_transform(df['sentiment'])

# %%
df
# Out:
#        overall  verified      reviewerID  \
# 0            5      True  A3CZ890UHC8HHZ
# 1            5     False  A125TMC44CJBKK
# 2            5      True  A3JDSBP01M7R2R
# 3            5      True  A2HT5WENL8E5S6
# 4            5     False   A7LAYX9R7IMOO
# ...        ...       ...             ...
# 73363        2     False  A1MB5HUA3WYEJC
# 73364        5      True  A2J4588ZHYJORN
# 73365        5      True  A2P06K653ZTGXN
# 73366        5      True  A1S8HP3G8DTMFH
# 73367        4      True  A1KYXIBRJS2JE9
#
#                                               reviewText  \
# 0      It diffuses a very mild light perfume, just wh...
# 1      All time favorite!!!! Wish they still carried ...
# 2                            One of my wife's favorites.
# 3      If you have body acne this product is a must. ...
# 4                            I really is what I expected
# ...                                                  ...
# 73363  When I heard about Rail Simulator I was happy ...
# ...

# %%
df = df.loc[df.verified, :]

# %%
df
# Out:
#        overall  verified      reviewerID  \
# 0            5      True  A3CZ890UHC8HHZ
# 2            5      True  A3JDSBP01M7R2R
# 3            5      True  A2HT5WENL8E5S6
# 5            5      True  A29PKN4LL05QGF
# 8            5      True   AD42QCRPG1RKG
# ...        ...       ...             ...
# 73361        5      True  A2RP3NEF3K3627
# 73364        5      True  A2J4588ZHYJORN
# 73365        5      True  A2P06K653ZTGXN
# 73366        5      True  A1S8HP3G8DTMFH
# 73367        4      True  A1KYXIBRJS2JE9
#
#                                               reviewText  \
# 0      It diffuses a very mild light perfume, just wh...
# 2                            One of my wife's favorites.
# 3      If you have body acne this product is a must. ...
# 5                         Lathers well and smells great.
# 8                        It was good, my loved her gift!
# ...                                                  ...
# 73361                                            Perfect
# ...

# %%
df.drop(['overall', 'verified', 'reviewerID'], axis=1, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10108\1541996746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['overall', 'verified', 'reviewerID'], axis=1, inplace=True)

# %%
df
# Out:
#                                               reviewText  \
# 0      It diffuses a very mild light perfume, just wh...
# 2                            One of my wife's favorites.
# 3      If you have body acne this product is a must. ...
# 5                         Lathers well and smells great.
# 8                        It was good, my loved her gift!
# ...                                                  ...
# 73361                                            Perfect
# 73364                                          very good
# 73365  does a great job at a great price.  Good quali...
# 73366  Microsoft's point system doesn't really make a...
# 73367  I already had the game, but I was buying it ag...
#
#                      summary  \
# 0            What I expected
# 2                 Five Stars
# 3      Acne Body Wash A MUST
# 5                 Five Stars
# 8                 Five Stars
# ...                      ...
# 73361             Five Stars
# 73364             Five Stars
# ...

# %%
df.reset_index(inplace=True)
df.drop('index', axis='columns', inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10108\1997736030.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('index', axis='columns', inplace=True)

# %%
df
# Out:
#                                               reviewText  \
# 0      It diffuses a very mild light perfume, just wh...
# 1                            One of my wife's favorites.
# 2      If you have body acne this product is a must. ...
# 3                         Lathers well and smells great.
# 4                        It was good, my loved her gift!
# ...                                                  ...
# 60177                                            Perfect
# 60178                                          very good
# 60179  does a great job at a great price.  Good quali...
# 60180  Microsoft's point system doesn't really make a...
# 60181  I already had the game, but I was buying it ag...
#
#                      summary  \
# 0            What I expected
# 1                 Five Stars
# 2      Acne Body Wash A MUST
# 3                 Five Stars
# 4                 Five Stars
# ...                      ...
# 60177             Five Stars
# 60178             Five Stars
# ...

# %%
df.to_csv('data/data_final/pre_summ.csv')
